# %% [markdown]
# # Notebooks {#sec-notebooks}

# %% [markdown]
# ## Scripts versus notebooks
#
# You have written a program, saved it in a file, and run it from the terminal. That is one way of running Python, and it is the way most Python in the world gets run. This chapter shows you the other way, the one you are looking at right now, because this page is itself a running Python program. The two ways are not the same, and the places where they differ are exactly the places where beginners get confused. So let us take them apart.

# %% [markdown]
# ## The script you already know
#
# Your `hello.py` is a script. It is a plain text file sitting on the disk with some Python code written in it. To run it, you go to the terminal and type:
#
# ```{.txt filename="Terminal"}
# python hello.py
# ```
#
# The program called `python` is the interpreter. It opens your file, reads the first line, does what it says, reads the next line, does what that one says, and carries on until there are no more lines. Then it stops and exits.
#
# Two things follow from that, and both of them matter more than they look.
#
# The order the lines appear in the file is the order in which they run. Nothing jumps around. If you want to know what a script does, you read it downward.
#
# The second is that every run starts from nothing. When the interpreter exits, everything it was holding is thrown away, because it was all in memory, and memory is emptied the moment a program ends. Run the script again tomorrow and it starts from a blank slate once more. A script therefore carries everything it needs inside itself. If it works today, it works tomorrow, on your machine or on someone else's, and that reliability is bought entirely by starting from nothing every single time.

# %% [markdown]
# ## Notebooks in VScode
#
# The notes you are reading are also notebooks you can run. Reading this page in a browser will teach you nothing, because this chapter is about clicking things. The week1 notebooks are already in the course folder, in the `week1` subfolder. Open the course folder in vscode and expand the week1 folder to show its contents. Then double-click the `notebooks-in-vscode.ipynb` file to open it and work through it there. Everything below assumes you are looking at the real notebook with a cursor in it.
#
# Every other chapter you fetch when we get to it, so that the notebook you work in is always the current version of the chapter you are reading. There is a **Download notebook** button in the margin of every chapter on the website so you can download the notebook and put it in the course folder.

# %% [markdown]
# ::: {.callout-note}
#
# ## Downloading Notebooks
#
# The notes you are reading are also notebooks you can run. Reading this page in a browser will teach you nothing, because this chapter is about clicking things. The week1 notebooks are already in the course folder, in the `week1` subfolder. Open the course folder in vscode and expand the week1 folder to show its contents. Then double-click the `notebooks-in-vscode.ipynb` file to open it and work through it there. Everything below assumes you are looking at the real notebook with a cursor in it.
#
# Every other chapter you fetch when we get to it, so that the notebook you work in is always the current version of the chapter you are reading. There is a **Download notebook** button in the margin of every chapter on the website so you can download the notebook and put it in the course folder.
#
# ## Getting notebooks from the terminal
#
# I also made you an easier way to get the notebooks. Say you want the notebook for the "Iteration" chapter, all you need to do is navigate to the course folder and run `pixi run get iteration`:
#
# ```{.txt filename="Terminal"}
# > pixi run get iteration
# Fetching https://munch-group.org/instructing-machines/notebooks/iteration.ipynb
#
# Saved iteration.ipynb. Open it in VS Code and pick the .pixi kernel.
# ```
#
# To see what you can ask for other than `iteration`, run it without a name:
#
# ```{.txt filename="Terminal"}
# > pixi run get
# ```
#
# If you already have a notebook of that name, yours is left exactly as it is and the fresh copy arrives beside it as `iteration-2.ipynb`. Nothing you have written is ever overwritten, so it is always safe to ask for a clean copy.
#
# :::

# %% [markdown]
# ## The notebook you are reading
#
# Now look at where you are. This page is a notebook, a file whose name ends in `.ipynb`. You can download it using the link in the margin and open it in VScode. Instead of one long stream of code, a notebook is built from cells. Some cells are text, like this one. Other cells hold code and can be run one at a time.
#
# Enough description. Run the cell below. Click it and press Shift and Enter together.

# %%
dna = "ATGGTGCATCTGACTCCTGAGGAGAAG"
len(dna)

# %% [markdown]
# Two things just happened. A small number appeared in brackets to the left of the cell, and the length of the string appeared underneath it even though you never wrote `print`. Hold on to both of those; we will come back to them.
#
# Now run the next cell.

# %%
dna.count("A")

# %% [markdown]
# That cell never mentions what `dna` is, and yet it worked. This is the whole difference in one line. Behind this page there is a Python process that has been running the entire time, and it is still running now. It is called the kernel. When you run a cell, the code in that cell is handed to that same living process, which does what it says and then waits for whatever you hand it next. The first cell put a string into that process and gave it the name `dna`. The second cell asked the same process about a name it already knew.
#
# So a notebook is not a file that the interpreter reads from top to bottom. It is a pile of small pieces of code that you hand, one piece at a time, to a session that remembers everything you have handed it so far.
#
# The number in brackets is the execution count, and it tells you the order in which you handed things over. The first cell you run in a session gets a `1`, the next gets a `2`, and so on. Run the same cell again and its number goes up. This is the notebook quietly telling you something important, which is that the kernel remembers the order you ran cells in, not the order the cells sit on the page. You can run the bottom cell first, then the top one, then the bottom one again, and the kernel will happily oblige. You can even delete a cell after running it, and the names it defined will still be sitting in the kernel, alive and usable, with nothing on the page left to explain where they came from.
#
# That is the notebook's great convenience and its great trap. It is a convenience because you can try one small thing, look at the answer, and try the next small thing, without rerunning your whole program each time. It is a trap because what you see on the page can stop matching what the kernel actually holds.
#
# The other loose end was the length appearing without `print`. When the last line of a cell is a bare expression, something that reduces to a value, the notebook displays that value for you. Only the last line, and only if it is an expression. An assignment like `dna = "ATG"` produces no value, so nothing is shown. This is a courtesy of the notebook, not a rule of Python. A script will print nothing at all unless you ask it to with `print`, which is one of the small ways that code moved out of a notebook stops behaving the way you remember.

# %% [markdown]
# #### Exercise {#sec-exercise-out-of-order}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Decide what will happen before you touch anything. Scroll back up to the cell that defines `dna`, change the string to `"GGGGG"`, and run only that cell. Then run the counting cell again. What number do you expect, and what do you get? Now change the string back and run the counting cell without rerunning the definition. What do you get, and why?

# %% [markdown]
# #### Exercise {#sec-exercise-restart-and-run-all}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Find the command in your editor that restarts the kernel and runs all the cells from the top. In VScode it sits at the top of the notebook. Predict what will happen to the execution counts before you use it, then use it and check.

# %% [markdown]
# ## Python and IPython
#
# There is a second thing going on that you have not been told about yet, and now is the time.
#
# If you type `ipython` in the terminal you launch a IPython, which presents you with an interactive prompt:
#
# ```
# In [1]:
# ```
#
# IPython is not a different language. It is the same Python, with a friendlier shell wrapped around it: it completes names when you press Tab, it colors your code as you type, it prints much nicer error messages, and if you put a question mark after a name it shows you the documentation for it. It also adds something Python itself does not have, which we are about to meet.
#
# And here is the point of this section. The kernel behind a Python notebook is IPython. That bracketed number next to your cells is IPython's counter, the same one that says `In [1]` at its terminal prompt. You have been using IPython since the first cell of this chapter without knowing it.

# %% [markdown]
# ## Two kinds of cells
#
# A notebook is a stack of cells, and there are two kinds.
#
# Text cells hold prose, written in a simple formatting language called Markdown. The paragraph you are reading is one of them. When a text cell is finished it is rendered, meaning you see the formatted result rather than the raw text you typed. Double-click one and it turns back into editable text; press Shift and Enter together and it renders again.
#
# Code cells hold Python. They have a run button on the left and a slot on the left of that where a number appears after they have been run. Everything in a code cell is Python, which means a line of prose typed into a code cell by mistake will produce a `SyntaxError`, and a line of Python typed into a text cell by mistake will simply sit there looking like a sentence and never run. Both mistakes are common and both are worth recognizing on sight.
#
# #### Exercise {#sec-exercise-edit-markdown}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Double-click this paragraph. You should see the raw Markdown, with the exercise heading above it starting with four hash marks. Add a sentence of your own at the end. Press Shift and Enter to render it back. Now double-click it again and remove your sentence. You have just done the two things you will do to every text cell for the rest of the term.

# %% [markdown]
# ## Choosing the kernel
#
# The cells are the notebook. The thing that actually runs your code is a separate program called the kernel, and it is a real Python interpreter living in the background with all your variables in it. The notebook sends a cell to the kernel, the kernel runs it and sends back whatever came out.
#
# Look at the top right of the notebook window. There is a button there naming the kernel this notebook is attached to. If it says something like Select Kernel, no interpreter is attached yet, and nothing will run until you attach one. Click it and choose the environment for this course. If you pick a different Python installation, your code will run, but the course tools will not be installed in it, and every `import` of a course package will fail with a `ModuleNotFoundError` that has nothing to do with your code. A large fraction of the confusing failures in the first weeks are a wrong kernel.
#
# You can ask the kernel what it is from inside the notebook.

# %%
import sys
sys.version.split()[0]

# %% [markdown]
# That is the version of Python answering. To find out which installation it came from, run `sys.executable` in a cell of your own; the path it returns should sit inside the course environment. Comparing that path with the name on the kernel button is how you settle an argument about which Python is actually running your code.
#
# #### Exercise {#sec-exercise-check-kernel}
#
# [SOLO](../intro/course-introduction.qmd#sec-badge-solo){.small}
#
# Make a new cell below this one, put `sys.executable` in it, and run it. Read the path. Then click the kernel button at the top right and read the name it shows. Satisfy yourself that they describe the same installation. Delete your cell when you are done.

# %% [markdown]
# ## Restarting the kernel
#
# Because the kernel keeps everything you have run, it will happily keep a variable you have since deleted from the page, a function whose definition you have changed, and a value from an experiment you abandoned twenty minutes ago. Code that leans on any of those looks like it works and will not work for anyone else.
#
# Restarting the kernel throws all of it away and gives you a fresh interpreter with nothing in it. Your cells and their text are untouched; only the memory is emptied. The Restart button is in the toolbar along the top of the notebook, next to a Clear Outputs button that wipes the displayed results without restarting anything, and next to Restart and Run All, which restarts and then runs every cell down the page in order.
#
# Restart and Run All is the one that matters. It is the only way to find out whether your notebook does what it appears to do, because it is the only way to run it the way a stranger would. Anything that survives that has been proved to work in page order. Anything that fails was depending on something that is not written down.
#
# #### Exercise {#sec-exercise-restart}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Run the cell below, so that `virus` exists in the kernel.

# %%
virus = "HIV"
virus

# %% [markdown]
# Now press Restart. Then run the cell below, and only that cell. Predict first what will happen, and be specific about the error you expect.

# %%
virus.lower()

# %% [markdown]
# You should get a `NameError` saying that `virus` is not defined, because the restart emptied the kernel and the cell that creates `virus` has not been run since. Now use Restart and Run All, and watch the whole page run from the top with the counts numbering themselves neatly downward. Both cells work again, because this time they ran in the order they are written.
#
# If a notebook of yours is behaving strangely and you cannot see why, restart and run all before you do anything else. Most of the time the strangeness is stale memory, and most of the rest of the time the restart turns a mystery into an error message you can read.

# %% [markdown]
# ## Running a code cell
#
# There are three ways to run the cell your cursor is in, and the difference between them is only where you end up afterward.
#
# Shift and Enter together runs the cell and moves the cursor to the next one, which is what you want when you are working down a page. Control and Enter together, or Command and Enter on a Mac, runs the cell and leaves the cursor where it is, which is what you want when you are editing one cell repeatedly until it works. Alt and Enter together, or Option and Enter on a Mac, runs the cell and makes a new empty one below it, which is what you want when you are building something up a piece at a time.
#
# Run the cell below with Shift and Enter.

# %%
dna = "ATGGTGCATCTGACTCCTGAGGAGAAG"
len(dna)

# %% [markdown]
# Two things happened. A number appeared in the brackets to the left of the cell, and the value `27` appeared underneath it.
#
# The number is the execution count. It says which run this was, counting every code cell you have run since the kernel started. The first cell you run gets `1`, the next gets `2`, and so on. If you run the same cell three times its number changes three times, because the count records runs and not cells.
#
# The value underneath appeared because the last line of the cell was an expression sitting on its own. A notebook shows you the value of the final expression as a courtesy, without you asking. This is a notebook habit rather than a Python rule: put `len(dna)` on its own line in a script and nothing at all appears on your screen.
#
# #### Exercise {#sec-exercise-execution-count}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Run the cell above two more times and watch the number in the brackets. Predict what it will say before each run. Then add a second line `dna.count("A")` below the `len(dna)` line, run it once more, and see which of the two values gets displayed. Work out the rule from what you observe.

# %% [markdown]
# ## Order on the page and order in time
#
# This is the part of notebooks that catches everyone, so it is worth meeting it deliberately rather than by accident at midnight.
#
# A script runs from top to bottom, always. A notebook runs in whatever order you clicked. The cells are laid out down the page, but the kernel remembers them in the order you ran them, and those two orders have nothing to do with each other. A notebook where you have been jumping around can show a page that reads perfectly and produces results that nobody could reproduce, including you, because the state that produced them came from a sequence of clicks that is not written down anywhere.
#
# The execution counts are the only record you have of that sequence. When you open somebody's notebook and the counts down the page read 4, 1, 9, 2, you are looking at a page that has never once been run in the order it is written.

# %%
codon_count = 64
codon_count

# %% [markdown]
# #### Exercise {#sec-exercise-run-out-of-order}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Click into the `dna` cell further up the page and run it again. Then come back down here and run the `codon_count` cell. Look at the execution counts on the two cells and confirm that the higher number is now on the cell that appears earlier on the page. That is a notebook telling you the truth about itself, and it is the only warning you will get.

# %% [markdown]
# ## Restart and run all
#
# The exercise you just did is the single most useful habit you can form about notebooks, so let us give it a name. Restarting the kernel throws away the running process and starts a fresh one that knows nothing. Running all the cells afterward feeds them back in, from the top, in page order. In other words, restarting and running all makes your notebook behave, for one run, like a script.
#
# Do this before you believe a notebook works, and certainly before you hand one to anybody else. A notebook that only works because of something you ran twenty minutes ago in a cell you have since deleted is a notebook that will fail for the next person who opens it, and that next person is often you, next week.

# %% [markdown]
# ### Magic commands {#sec-magics}
#
# Run this cell.

# %%
# %whos

# %% [markdown]
# What you just ran is not Python. It is a magic command, one of IPython's own commands, and `%whos` asks it to list every name the kernel is currently holding. Look at that list and notice that `dna` is in it. That table is the kernel's memory made visible, and it is a good thing to run whenever a notebook starts behaving strangely.
#
# Magic commands come in two shapes. A line magic starts with one percent sign and affects only its own line, so `%whos` above is a line magic. A cell magic starts with two percent signs, must be the very first line of the cell, and takes charge of everything below it in that cell. Every widget in this course is a cell magic, which is why they all look like `%%steps`, `%%puzzle`, `%%codelens` and, in a moment, `%%sandbox`.
#
# Because magics belong to IPython and not to Python, they only work where IPython is running, which means in a notebook or at the `ipython` prompt. Copy `%whos` into `hello.py`, run `python hello.py`, and you will get a `SyntaxError`, because the plain interpreter has never heard of it. Keep that in mind the next time you move code out of a notebook and into a script and it stops working for no visible reason.

# %% [markdown]
# #### Exercise {#sec-exercise-ask-about-magics}
#
# [AI: Explainer](course-introduction.qmd#sec-badge-explainer){.small}
#
# Ask the assistant to explain the difference between a line magic and a cell magic, and to give you three examples of each. Then take each example it gives you and try it in a cell here. Some will work, some will not exist, and some will turn out to be the wrong shape. Note in your logbook which of its examples survived contact with the machine.

# %% [markdown]
# ## When the kernel's memory gets in the way
#
# The kernel's long memory is a gift when you are exploring and a menace when you are learning.
#
# Suppose an exercise asks you to run a piece of code that should fail, so that you can read the error message. If you happen to have defined that name in some other cell half an hour ago, the code will not fail at all, and the lesson evaporates. Or suppose you write a small piece of code, run it, see it work, and conclude that it is correct. It may be correct. It may also be leaning on a name that a cell somewhere above quietly left lying around, in which case it will collapse the moment it is moved anywhere else.
#
# What we want, for a lot of the exercises in this book, is a cell that behaves like a script: one that starts from nothing, contains everything it needs, and leaves nothing behind. That is what the sandbox is for.

# %% [markdown]
# ## The sandbox
#
# Run this cell once. It brings in the tool and registers the magic with IPython.

# %%
import sandbox_widget

# %% [markdown]
# Now run this one.

# %%
# %%sandbox
# print("Hello from a fresh interpreter")

# %% [markdown]
# The output turned up in a shaded box below the cell instead of in the usual place, which is your visual cue that this cell was not run the way the others were.
#
# Here is what makes it different. Predict what the next cell will do before you run it. Remember that `dna` has been sitting in the kernel since the top of the chapter, and that the cell below asks for it by name. This cell is meant to fail.

# %%
# %%sandbox
# print("The sandbox is about to look for dna.")
# print(dna)

# %% [markdown]
# It printed the first line and then raised a `NameError` on the second, and both the printed line and the full traceback landed in the box. The notebook itself carried on untroubled.
#
# Now name what you saw. `%%sandbox` is a cell magic that takes everything below it and runs it in a brand new Python interpreter, a separate process started for that one cell and thrown away the moment it finishes. Nothing that the notebook knows about is visible inside it. The kernel has a `dna`, and the sandbox has never heard of it, because the sandbox is not the kernel.
#
# The barrier runs both ways. Run the next two cells in order.

# %%
# %%sandbox
# codon_count = 64
# print(codon_count)

# %%
print("codon_count" in globals())

# %% [markdown]
# The sandbox cell made a `codon_count` and printed it quite happily. The ordinary cell that followed asked the kernel whether it has ever heard of that name, and the answer is `False`. Whatever the sandbox does stays in the sandbox, and when its process ends, all of it goes.
#
# So a `%%sandbox` cell is a tiny script that happens to live inside a notebook. It runs from nothing, top to bottom, and it has to carry everything it needs, including its own `import` lines. Anything it defines dies with it, and any mistake it makes is caught and shown to you rather than left to poison the rest of the session.
#
# That last part is why so many exercises in this book use it. A cell that is supposed to break can be relied upon to break, every time, for everybody, no matter what you ran before it.

# %% [markdown]
# #### Exercise {#sec-exercise-two-cells}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# The two cells below have the same last line. Decide what each one will show before you run either of them, and write your two predictions down. Then run them from the top.

# %%
message = "ATG"
print(message * 3)

# %%
# %%sandbox
# print(message * 3)

# %% [markdown]
# #### Exercise {#sec-exercise-repair}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Write a new cell that starts with `%%sandbox` and that prints `ATGATGATG` successfully. You may not change any cell above it. There is only one way to do this, and working out what it is tells you that you have understood the section.

# %% [markdown]
# #### Exercise {#sec-exercise-explain-traceback}
#
# [AI: Explainer](course-introduction.qmd#sec-badge-explainer){.small}
#
# Copy the traceback from the failing sandbox cell above, paste it to the assistant, and ask it to explain what went wrong and why. Read its answer carefully. It has not seen this chapter and does not know that the cell was run in a separate process, so watch for the moment it explains the error confidently in terms it has invented. Write down in your logbook what it got right, what it got wrong, and how you knew.

# %% [markdown]
# ## The other magics in this book
#
# Every widget you will meet in this course works the same way as the sandbox: you import it once near the top of the notebook, and after that a cell magic is available for the rest of the session. `%%steps` shows you the substitution and reduction steps inside a single statement. `%%puzzle` gives you shuffled lines to put back in order. `%%codelens` walks through a piece of code one statement at a time and draws what is in memory as it goes. And `%%sandbox` runs a cell as though it were a script.
#
# If a magic reports that it does not exist, the answer is almost always that you have not run its import in this kernel, or that you restarted the kernel since you did.

# %% [markdown]
# ## Which one to use, and when
#
# Use a notebook when you are exploring, when you want to see an answer before deciding on the next step, and when the text and the code belong together, which is why the notes in this book are notebooks. Use a script when you want something to run the same way every time, when you want to hand it to somebody else, and when the point is the result rather than the journey.
#
# And use the two habits from this chapter to keep yourself out of trouble. When you want to know whether a notebook really works, restart the kernel and run everything from the top. When you want to know whether a piece of code stands on its own, put it in a `%%sandbox` cell and watch it either run or fall over.
#
# That second habit is going to matter a great deal once the assistant starts writing code for you. Code pasted into a notebook that appears to work may only be working because of something the kernel already had lying around from an earlier cell, and that is a very easy way to accept a piece of code that is broken. Dropping it into a sandbox forces it to prove that it stands up by itself. The assistant predicts that its code works. The sandbox is one of the ways you make it prove it.

# %% [markdown]
# #### Exercise {#sec-exercise-logbook}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Make this week's logbook entry. Describe in a few sentences, in your own words and without looking back at this chapter, what the kernel is and why a `%%sandbox` cell cannot see it. If you cannot do it without looking, read the chapter again and then try once more.

# %% [markdown]
# ## Adding, moving, copying and deleting cells
#
# Hover in the space between two cells and a small toolbar appears offering a new code cell or a new text cell at that spot. That is the easiest way to add one, and it is the way you will use most of the time.
#
# Everything else is faster from the keyboard, and to use the keyboard you need to know about the two modes a cell can be in. When your cursor is inside a cell, typing changes its contents, and that is edit mode. Press Escape and the cursor leaves the cell; the cell is still selected, shown by a bar down its left side, but now the keys are commands rather than text. That is command mode. Press Enter to go back into the cell.
#
# In command mode, `A` makes a new cell above the selected one and `B` makes one below. `M` turns the selected cell into a text cell and `Y` turns it back into a code cell. `C` copies the selected cell, `X` cuts it, and `V` pastes what you copied below the selection. Pressing `D` twice, quickly, deletes the selected cell, and `Z` undoes that, which is a good pair to know in that order.
#
# To move a cell up or down, use the two arrow buttons in the toolbar that appears at the top right of the selected cell, or pick the cell up by its left edge and drag it. Every one of these commands also lives in the Command Palette, which you open with Control and Shift and P together, or Command and Shift and P on a Mac. Typing part of a command name there shows you the command along with whatever keyboard shortcut your copy of VScode has assigned to it, which is the reliable way to answer any shortcut question rather than trusting a list in a book.
#
# #### Exercise {#sec-exercise-cell-surgery}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Do all of this without touching the mouse after the first click. Click on this cell and press Escape to get into command mode. Press `B` to make a new cell below, press Enter to get into it, and type `print("first")`. Press Escape, then `B` again, then Enter, and type `print("second")`. Run both. Now select the `print("first")` cell and move it below the other one using the arrows in its toolbar, and run both again in page order to confirm the output changed. Finally select each of your two cells in turn and press `D` twice to remove them, leaving the page as you found it. If you delete one cell too many, press `Z`.

# %% [markdown]
# ## What a notebook is on disk
#
# The `.ipynb` file holds your cells, in page order, along with whatever output each cell produced the last time it ran. That is why you can send someone a notebook and they see your results before running anything, and it is also why the file changes every time you run a cell even if you typed nothing. It is worth knowing when you start putting notebooks into a repository and wonder why a file you only looked at is showing up as modified.
#
# A notebook is a good place to work something out, with prose and code and results interleaved on one page. A `.py` file is a better place for code that other code depends on, because it starts from nothing every time and therefore says exactly what it needs.
#
# #### Exercise {#sec-exercise-own-notebook}
#
# [SOLO](course-introduction.qmd#sec-badge-solo){.small}
#
# Make a new notebook of your own, from the Command Palette or from File and New File. Attach the course kernel to it. Give it a text cell with a heading and a sentence saying what it is for, then a code cell that stores a DNA string in a variable, then another that prints its length. Restart and run all, and confirm that the counts read 1 and 2 down the page. Save it somewhere you will find it again. That notebook is where you should try things out this week, and getting it set up now means the next time you have a question you can answer it in thirty seconds instead of ten minutes.
