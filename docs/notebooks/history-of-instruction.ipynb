# %% [markdown]
# # Instruction through the ages {#sec-history-of-instruction}
#
# *Some text.*
#
# ## Machine instructions
#
# Text.
#
# ## Compilers
#
# Text.
#
# ## Interpreted languages
#
# Text.
#
# ## AI
#
# Text.
