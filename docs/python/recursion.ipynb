# %% [markdown]
# # Recursion {#sec-recursion}

# %% [markdown]
# <!-- $$f(x) = f(x-1)$$ {#eq:some_label}
#
# Equation [@eq:some_label] -->
#
# ## Recursion
#
# PLACEHOLDER PAGE
#
# ## Divide and conquer
#
# PLACEHOLDER PAGE
#
# #### Exercise
#
# PLACEHOLDER PAGE
