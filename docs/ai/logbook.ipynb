# %% [markdown]
# # Log book {.unnumbered}

# %% [markdown]
# ## Week 1

# %% [markdown]
# ## Week 2

# %% [markdown]
# ## Week 3

# %% [markdown]
# ## Week 4

# %% [markdown]
# ## Week 5

# %% [markdown]
# ## Week 6

# %% [markdown]
# ## Week 7

# %% [markdown]
# ## Week 8

# %% [markdown]
# ## Week 9

# %% [markdown]
# ## Week 10

# %% [markdown]
# ## Week 11

# %% [markdown]
# ## Week 12

# %% [markdown]
# ## Week 13

# %% [markdown]
# ## Week 14
