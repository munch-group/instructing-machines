# %% [markdown]
# # AI: Let it explain, then confirm {#sec-explain-then-confirm}
#
# *The assistant as Explainer: an explanation is useful but provisional.*
#
# Paste something, a traceback or a piece of code, ask the assistant to explain it, read the explanation, and only then run the actual code and read what really happens. An explanation you have not confirmed is a plausible story, not knowledge. Does what actually happened match what the AI claims in every detail?
#
# 1. **Paste.** Give the assistant the error or the code, with no extra hints about what you already suspect.
# 2. **Read the explanation.** Note the specific claim it makes: which line is at fault, what value caused it, what the code will print.
# 3. **Confirm.** Run the code yourself. Compare what actually happened, line for line, against the specific claim, not just the general vibe of it.

# %% [markdown]
# ## Syntax errors
#
# Each snippet below fails before it even starts running. Read the assistant's explanation of *why*, then run the snippet yourself in a new code block and confirm that the error message matches its story exactly, not approximately.

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# def gc_content(dna:
#     return dna.count('G') / len(dna)
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# sequences = ['ATG', 'GCC', 'TAA'
# print(sequences)
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# for base in 'ATGC':
# print(base)
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# name = 'Preben'
# print('Hello, ' name)
# ```

# %% [markdown]
# ## Runtime errors
#
# These run, and then fail partway through. Read the traceback yourself first, note the line and the error name, before you ask the assistant anything, so you have your own prediction of the cause to compare against its explanation.

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# counts = {'A': 4, 'T': 3, 'G': 2}
# print(counts['C'])
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# bases = ['A', 'T', 'G', 'C']
# print(bases[4])
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# def average_length(sequences):
#     total = sum(len(s) for s in sequences)
#     return total / len(sequences)
#
# print(average_length([]))
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# def combine(dna, count):
#     return dna * count
#
# print(combine('ATG', '3'))
# ```

# %% [markdown]
# ## Explaining what it does
#
# Here is some code that runs. Predict the output each code block generates. Then ask the assistant what it the code does and what why it ends up printing what it does. Compare to your prediction.

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# dna = 'ATGGCCTAA'
# print(dna[::-1])
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# counts = {}
# for base in 'ATGGCCA':
#     counts[base] = counts.get(base, 0) + 1
# print(counts)
# ```

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# ```python
# sequences = ['ATG', 'GCCTAA', 'TT']
# longest = max(sequences, key=len)
# print(longest)
# ```

# %% [markdown]
# ## Bring your own blunders

# %% [markdown]
# #### Exercise
#
# [SOLO](../intro/course-introduction.qmd#sec-badge-solo){.small}
#
# Find an error message you got yourself working on code this week. One that confused you at the time. Write down what you think was happening using what you have learned since then.

# %% [markdown]
# #### Exercise
#
# [AI: Explainer](../intro/course-introduction.qmd#sec-badge-explainer){.small}
#
# Ask the assistant to explain the same error. Compare its explanation to the one you wrote yourself. Confirm both explanations against the actual running code. Which explanation was was better and most correct?
