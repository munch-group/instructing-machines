# %% [markdown]
# # BioPython {#sec-biopython}
#
# *A bird's eye view of Biopython to give you an impression of what you can do if you know just a little bit about modules classes*
#
# ## The Seq class
#
#
# ## Reading and writing sequence formats
