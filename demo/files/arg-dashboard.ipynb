# %%
import piplite
await piplite.install("arg-dashboard")
await piplite.install("jupyter>=1.1.1,<2")
await piplite.install("dash>=3.4.0,<4")
await piplite.install("dash-bootstrap-components>=2.0.4,<3")
await piplite.install("pandas>=3.0.0,<4")
await piplite.install("networkx>=3.6.1,<4")
await piplite.install("jupyter-dash>=0.4.2,<0.5")
await piplite.install("plotly>=6.5.2,<7")
await piplite.install("seaborn>=0.13.2,<0.14")
await piplite.install("quartodoc>=0.11.1,<0.12")
await piplite.install("quarto>=1.8.27,<2")
await piplite.install("pip>=26.0,<27")
await piplite.install("pytest>=9.0.2,<10")

# %%
import os
os.environ['no_proxy'] = os.environ.get('no_proxy', '') + ',127.0.0.1,localhost'
from arg_dashboard import app

app.run(mode='inline', jupyter_height=800)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
