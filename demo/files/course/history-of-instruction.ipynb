# %% [markdown]
# # Instruction through the ages
#
# *Some text.*
#
# ## Machine instructions {.unnumbered}
#
# Text.
#
# ## Compilers {.unnumbered}
#
# Text.
#
# ## Interpreted languages {.unnumbered}
#
# Text.
#
# ## AI {.unnumbered}
#
# Text.
