# %% [markdown]
# ---
# execute:
#   enabled: false
# ---
#
# # Widget demo {#sec-widget-demo}

# %% [markdown]
# ::: {.column-margin}
#
# {{< video videos/hello.mp4 >}}
#
# :::

# %% [markdown]
# ```python
# # Run this in JupyterLite to install the widgets used below
# %pip install -q anywidget codelens-widget puzzle-widget steps-widget turtle-widget
# ```

# %% [markdown]
# ## Sandbox cell magic

# %%
import sandbox_widget

# %%
# %%sandbox
#
# variable = 'hello world'
# print(variable)

# %% [markdown]
# ## Codelens cell magic

# %%
import codelens_widget

# %%
# %%codelens
#
# def insertion_sort(a):
#     for i in range(1, len(a)):
#         key = a[i]
#         j = i - 1
#         while j >= 0 and a[j] > key:
#             a[j + 1] = a[j]
#             j -= 1
#         a[j + 1] = key
#     return a
#
# data = [5, 2, 9, 1]
# insertion_sort(data)

# %% [markdown]
# ## Puzzle cell magic

# %%
import puzzle_widget

# %%
# %%puzzle 44
#
# total
# total = total + z
# z = 2
# total = x * y
# y = 6
# x = 7

# %%
# %%puzzle 'HELLO, WORLD'
#
# greeting.upper()
# greeting = 'hello, ' + name
# name = 'world'

# %% [markdown]
# ## Steps cell magic

# %%
import steps_widget

# %%
# %%steps
#
# s = 'Hej {}'
# l = [1, 2, 3]
# greeting = s.format('Kasper').upper()[0:3]  # PRINT STEPS
# total = l[0] + l[1] + l[2]  # PRINT STEPS

# %%
# %%steps
# 3 + 2 * 4 + 9 # PRINT STEPS

# %%
# %%steps
# x = 0
# y = 3
# result = x and y or 7  # PRINT STEPS

# %% [markdown]
# ## Turtle cell magic

# %%
from turtle_widget import Turtle

# %%
t = Turtle()
t.speed(6)
for _ in range(4):
    t.forward(120)
    t.left(90)

# %%
import vscodenb
import seaborn as sns
data = sns.load_dataset('penguins')
data.head()

# %% [markdown]
# ## Interactive plotting with Seaborn

# %%
from iplot_widget import iplot

# %%
iplot(data)

# %%
import seaborn as sns
sns.set_style({'style': 'darkgrid', 'palette': 'viridis'})                             
g = sns.displot(data, x='bill_depth_mm', y='bill_length_mm', hue='sex', col='species', palette='muted', height=3.3309381582882542, col_wrap=3, kind='kde')
g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.tight_layout() ;
