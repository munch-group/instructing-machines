# %% [markdown]
# # Solving `alignmentproject` with the check widget
#
# *Compute a global pairwise alignment of two DNA sequences (Needleman–Wunsch).*
#
# This notebook shows how you solve the project and check your work as you go, using the `%%test` cell magic. Put your function definitions in a `%%test alignmentproject` cell and run it — the checks appear right below, with a ✓ or ✗ per function and any functions you still have to write listed as *not defined yet*.
#
# > Run this notebook from inside its own `alignmentproject/` folder, so the test file `test_alignmentproject.py` and any data files are found.
#
# There is a second way to work: write your functions in the file `alignmentproject.py` and, in a normal cell, run `check("alignmentproject")` — but here we keep everything in the notebook.

# %%
import im_pytest   # registers the %%test magic and check()

# %% [markdown]
# ## A first attempt
#
# We start with most of the solution written, but `align` still to do. Run the checks and see what's left:

# %%
# %%test alignmentproject
# #############################################################
# # Reference solution for the pairwise-alignment project.
# #############################################################
#
# def print_dp_matrix(seq1, seq2, matrix):
#     max_len = max(len(str(cell)) for row in matrix for cell in row)
#     fmt = "{{:>{}}}".format(max_len+1)
#     row_fmt = fmt * (len(matrix[0])+1) + '\n'
#     mat_fmt = row_fmt *  (len(matrix)+1)
#     seq1 = ' ' + seq1
#     seq2 = ' ' + seq2
#     lst = [' '] + list(seq2)
#     for i in range(len(seq1)):
#         lst.extend([seq1[i]] + list(map(repr, matrix[i])))
#     print(mat_fmt.format(*lst))
#
#
# def empty_matrix(m, n):
#     matrix = []
#     for i in range(m):
#         row = []
#         for j in range(n):
#             row.append(None)
#         matrix.append(row)
#     return matrix
#
#
# def prepare_matrix(m, n, gap_score):
#     matrix = empty_matrix(m, n)
#     for i in range(len(matrix)):
#         matrix[i][0] = gap_score * i
#     for j in range(len(matrix[0])):
#         matrix[0][j] = gap_score * j
#     return matrix
#
#
# def fill_matrix(seq1, seq2, score_matrix, gap_score):
#     matrix = prepare_matrix(len(seq1)+1, len(seq2)+1, gap_score)
#     for i in range(1, len(seq1)+1):
#         for j in range(1, len(seq2)+1):
#             base1 = seq1[i-1]
#             base2 = seq2[j-1]
#             diag = matrix[i-1][j-1] + score_matrix[base1][base2]
#             left = matrix[i][j-1] + gap_score
#             up = matrix[i-1][j] + gap_score
#             matrix[i][j] = max(left, up, diag)
#     return matrix
#
#
# # --- Provided verbatim in the write-up ---
#
# def get_traceback_arrow(matrix, row, col, match_score, gap_score):
#
#     # yellow cells:
#     score_diagonal = matrix[row-1][col-1]
#     score_left = matrix[row][col-1]
#     score_up = matrix[row-1][col]
#
#     # gree cell:
#     score_current = matrix[row][col]
#
#     if score_current == score_diagonal + match_score:
#         return 'diagonal'
#     elif score_current == score_left + gap_score:
#         return 'left'
#     elif score_current == score_up + gap_score:
#         return 'up'
#
#
# def trace_back(seq1, seq2, matrix, score_matrix, gap_score):
#
#     # Strings to store the growing alignment strings:
#     aligned1 = ''
#     aligned2 = ''
#
#     # The row and col index of the bottom right cell:
#     row = len(seq1)
#     col = len(seq2)
#
#     # Keep stepping backwards through the matrix untill
#     # we get to the top row or the left col:
#     while row > 0 and col > 0:
#
#         # The two bases we available to match:
#         base1 = seq1[row-1]
#         base2 = seq2[col-1]
#
#         # The score for mathing those two bases:
#         match_score = score_matrix[base1][base2]
#
#         # Find out which cell the score in the current cell was derived from:
#         traceback_arrow = get_traceback_arrow(matrix, row, col, match_score, gap_score)
#
#         if traceback_arrow == 'diagonal':
#                 # last column of the sub alignment is base1 over base2:
#             aligned1 = base1 + aligned1
#             aligned2 = base2 + aligned2
#             # next cell is the diagonal cell:
#             row -= 1
#             col -= 1
#         elif traceback_arrow == 'up':
#                 # last column in the sub alignment is base1 over a gap:
#             aligned1 = base1 + aligned1
#             aligned2 = '-' + aligned2
#             # next cell is the cell above:
#             row -= 1
#         elif traceback_arrow == 'left':
#                 # last column in the sub alignment is a gap over base2:
#             aligned1 = '-' + aligned1
#             aligned2 = base2 + aligned2
#             # next cell is the cell to the left:
#             col -= 1
#
#     # If row is not zero, step along the top row to the top left cell:
#     while row > 0:
#         base1 = seq1[row-1]
#         aligned1 = base1 + aligned1
#         aligned2 = '-' + aligned2
#         row -= 1
#
#     # If col is not zero, step upwards in the left col to the top left cell:
#     while col > 0:
#         base2 = seq2[col-1]
#         aligned1 = '-' + aligned1
#         aligned2 = base2 + aligned2
#         col -= 1
#
#     return [aligned1, aligned2]
# Out:
# Report(project='alignmentproject', outcomes=[Outcome(name='kmt', status='error', message="raised TimeoutError: [Errno 60] Operation timed out: '/Users/kmt/OneDrive - Aarhus universitet/__init__.py'")], undefined=[], stdout='', traceback='\x1b---------------------------------------------------------------------------\x1b\n\x1bTimeoutError\x1b                              Traceback (most recent call last)\n\x1bFile \x1b\x1b~/.local/lib/python3.13/site-packages/_pytest/runner.py:361\x1b, in \x1bCallInfo.from_call\x1b\x1b(cls, func, when, reraise)\x1b\n\x1b    359\x1b instant = timing.Instant()\n\x1b    360\x1b \x1btry\x1b:\n\x1b--> \x1b\x1b361\x1b     result: TResult | \x1bNone\x1b = \x1bfunc\x1b\x1b(\x1b\x1b)\x1b\n\x1b    362\x1b \x1bexcept\x1b \x1bBaseException\x1b:\n\x1b    363\x1b     excinfo = ExceptionInfo.from_current()\n\n\x1bFile \x1b\x1b~/.local/lib/python3.13/site-packages/_pytest/runner.py:406\x1b, in \x1bpytest_make_collect_report.<locals>.collect\x1b\x1b()\x1b\n\x1b    396\x1b \x1bif\x1b \x1bisinstance\x1b(collector, Directory):\n\x1b    397\x1b     collector.config.pluginmanager._loadconftestmodules(\n\x1b    398\x1b         collector.path,\n\x1b    399\x1b         collector.config.getoption(\x1b"\x1b\x1bimportmode\x1b\x1b"\x1b),\n\x1b   (...)\x1b\x1b    403\x1b         ),\n\x1b    404\x1b     )\n\x1b--> \x1b\x1b406\x1b \x1breturn\x1b \x1blist\x1b\x1b(\x1b\x1bcollector\x1b\x1b.\x1b\x1bcollect\x1b\x1b(\x1b\x1b)\x1b\x1b)\x1b\n\n\x1bFile \x1b\x1b~/.local/lib/python3.13/site-packages/_pytest/main.py:575\x1b, in \x1bDir.collect\x1b\x1b(self)\x1b\n\x1b    573\x1b     \x1bif\x1b ihook.pytest_ignore_collect(collection_path=path, config=config):\n\x1b    574\x1b         \x1bcontinue\x1b\n\x1b--> \x1b\x1b575\x1b col = \x1bihook\x1b\x1b.\x1b\x1bpytest_collect_directory\x1b\x1b(\x1b\x1bpath\x1b\x1b=\x1b\x1bpath\x1b\x1b,\x1b\x1b \x1b\x1bparent\x1b\x1b=\x1b\x1bself\x1b\x1b)\x1b\n\x1b    576\x1b \x1bif\x1b col \x1bis\x1b \x1bnot\x1b \x1bNone\x1b:\n\x1b    577\x1b     \x1byield\x1b col\n\n\x1bFile \x1b\x1b~/.local/lib/python3.13/site-packages/pluggy/_hooks.py:512\x1b, in \x1bHookCaller.__call__\x1b\x1b(self, **kwargs)\x1b\n\x1b    510\x1b firstresult = \x1bself\x1b.spec.opts.get(\x1b"\x1b\x1bfirstresult\x1b\x1b"\x1b, \x1bFalse\x1b) \x1bif\x1b \x1bself\x1b.spec \x1belse\x1b \x1bFalse\x1b\n\x1b    511\x1b \x1b# Copy because plugins may register other plugins during iteration (#438).\x1b\n\x1b--> \x1b\x1b512\x1b \x1breturn\x1b \x1bself\x1b\x1b.\x1b\x1b_hookexec\x1b\x1b(\x1b\x1bself\x1b\x1b.\x1b\x1bname\x1b\x1b,\x1b\x1b \x1b\x1bself\x1b\x1b.\x1b\x1b_hookimpls\x1b\x1b.\x1b\x1bcopy\x1b\x1b(\x1b\x1b)\x1b\x1b,\x1b\x1b \x1b\x1bkwargs\x1b\x1b,\x1b\x1b \x1b\x1bfirstresult\x1b\x1b)\x1b\n\n\x1bFile \x1b\x1b~/.local/lib/python3.13/site-packages/pluggy/_manager.py:120\x1b, in \x1bPluginManager._hookexec\x1b\x1b(self, hook_name, methods, kwargs, firstresult)\x1b\n\x1b    111\x1b \x1bdef\x1b\x1b \x1b\x1b_hookexec\x1b(\n\x1b    112\x1b     \x1bself\x1b,\n\x1b    113\x1b     hook_name: \x1bstr\x1b,\n\x1b   (...)\x1b\x1b    118\x1b     \x1b# called from all hookcaller instances.\x1b\n\x1b    119\x1b     \x1b# enable_tracing will set its own wrapping function at self._inner_hookexec\x1b\n\x1b--> \x1b\x1b120\x1b     \x1breturn\x1b \x1bself\x1b\x1b.\x1b\x1b_inner_hookexec\x1b\x1b(\x1b\x1bhook_name\x1b\x1b,\x1b\x1b \x1b\x1bmethods\x1b\x1b,\x1b\x1b \x1b\x1bkwargs\x1b\x1b,\x1b\x1b \x1b\x1bfirstresult\x1b\x1b)\x1b\n\n    \x1b[... skipping hidden 2 frame]\x1b\n\n\x1bFile \x1b\x1b~/.local/lib/python3.13/site-packages/_pytest/python.py:186\x1b, in \x1bpytest_collect_directory\x1b\x1b(path, parent)\x1b\n\x1b    184\x1b pkginit = path / \x1b"\x1b\x1b__init__.py\x1b\x1b"\x1b\n\x1b    185\x1b \x1btry\x1b:\n\x1b--> \x1b\x1b186\x1b     has_pkginit = \x1bpkginit\x1b\x1b.\x1b\x1bis_file\x1b\x1b(\x1b\x1b)\x1b\n\x1b    187\x1b \x1bexcept\x1b \x1bPermissionError\x1b:\n\x1b    188\x1b     \x1b# See https://github.com/pytest-dev/pytest/issues/12120#issuecomment-2106349096. ...

# %% [markdown]
# The widget shows `align` as *not defined yet*. Now we add it and run again.

# %% [markdown]
# ## The finished solution
#
# All functions written — every check should pass:

# %%
# %%test alignmentproject
# #############################################################
# # Reference solution for the pairwise-alignment project.
# #############################################################
#
# def print_dp_matrix(seq1, seq2, matrix):
#     max_len = max(len(str(cell)) for row in matrix for cell in row)
#     fmt = "{{:>{}}}".format(max_len+1)
#     row_fmt = fmt * (len(matrix[0])+1) + '\n'
#     mat_fmt = row_fmt *  (len(matrix)+1)
#     seq1 = ' ' + seq1
#     seq2 = ' ' + seq2
#     lst = [' '] + list(seq2)
#     for i in range(len(seq1)):
#         lst.extend([seq1[i]] + list(map(repr, matrix[i])))
#     print(mat_fmt.format(*lst))
#
#
# def empty_matrix(m, n):
#     matrix = []
#     for i in range(m):
#         row = []
#         for j in range(n):
#             row.append(None)
#         matrix.append(row)
#     return matrix
#
#
# def prepare_matrix(m, n, gap_score):
#     matrix = empty_matrix(m, n)
#     for i in range(len(matrix)):
#         matrix[i][0] = gap_score * i
#     for j in range(len(matrix[0])):
#         matrix[0][j] = gap_score * j
#     return matrix
#
#
# def fill_matrix(seq1, seq2, score_matrix, gap_score):
#     matrix = prepare_matrix(len(seq1)+1, len(seq2)+1, gap_score)
#     for i in range(1, len(seq1)+1):
#         for j in range(1, len(seq2)+1):
#             base1 = seq1[i-1]
#             base2 = seq2[j-1]
#             diag = matrix[i-1][j-1] + score_matrix[base1][base2]
#             left = matrix[i][j-1] + gap_score
#             up = matrix[i-1][j] + gap_score
#             matrix[i][j] = max(left, up, diag)
#     return matrix
#
#
# # --- Provided verbatim in the write-up ---
#
# def get_traceback_arrow(matrix, row, col, match_score, gap_score):
#
#     # yellow cells:
#     score_diagonal = matrix[row-1][col-1]
#     score_left = matrix[row][col-1]
#     score_up = matrix[row-1][col]
#
#     # gree cell:
#     score_current = matrix[row][col]
#
#     if score_current == score_diagonal + match_score:
#         return 'diagonal'
#     elif score_current == score_left + gap_score:
#         return 'left'
#     elif score_current == score_up + gap_score:
#         return 'up'
#
#
# def trace_back(seq1, seq2, matrix, score_matrix, gap_score):
#
#     # Strings to store the growing alignment strings:
#     aligned1 = ''
#     aligned2 = ''
#
#     # The row and col index of the bottom right cell:
#     row = len(seq1)
#     col = len(seq2)
#
#     # Keep stepping backwards through the matrix untill
#     # we get to the top row or the left col:
#     while row > 0 and col > 0:
#
#         # The two bases we available to match:
#         base1 = seq1[row-1]
#         base2 = seq2[col-1]
#
#         # The score for mathing those two bases:
#         match_score = score_matrix[base1][base2]
#
#         # Find out which cell the score in the current cell was derived from:
#         traceback_arrow = get_traceback_arrow(matrix, row, col, match_score, gap_score)
#
#         if traceback_arrow == 'diagonal':
#                 # last column of the sub alignment is base1 over base2:
#             aligned1 = base1 + aligned1
#             aligned2 = base2 + aligned2
#             # next cell is the diagonal cell:
#             row -= 1
#             col -= 1
#         elif traceback_arrow == 'up':
#                 # last column in the sub alignment is base1 over a gap:
#             aligned1 = base1 + aligned1
#             aligned2 = '-' + aligned2
#             # next cell is the cell above:
#             row -= 1
#         elif traceback_arrow == 'left':
#                 # last column in the sub alignment is a gap over base2:
#             aligned1 = '-' + aligned1
#             aligned2 = base2 + aligned2
#             # next cell is the cell to the left:
#             col -= 1
#
#     # If row is not zero, step along the top row to the top left cell:
#     while row > 0:
#         base1 = seq1[row-1]
#         aligned1 = base1 + aligned1
#         aligned2 = '-' + aligned2
#         row -= 1
#
#     # If col is not zero, step upwards in the left col to the top left cell:
#     while col > 0:
#         base2 = seq2[col-1]
#         aligned1 = '-' + aligned1
#         aligned2 = base2 + aligned2
#         col -= 1
#
#     return [aligned1, aligned2]
#
#
# def align(seq1, seq2, score_matrix, gap_score):
#     dp = fill_matrix(seq1, seq2, score_matrix, gap_score)
#     return trace_back(seq1, seq2, dp, score_matrix, gap_score)
